# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import dowhy
from dowhy import CausalModel
import dowhy.datasets

from IPython.display import Image, display

# %%
normalised_key_atom1_data = pd.read_csv("/home/shmh4/Downloads/normalised_key_atom1_data_10.2020")

# %%
normalised_key_atom1_data = normalised_key_atom1_data.drop(columns = ['Unnamed: 0', 'HO2_ATHOS', 'NO_CL', 'H2O2_CIT'])
normalised_key_atom1_data
# Out:
#         OH_ATHOS   H2O_DLH  CH4_NOAA   CO_NOAA    NO2_CL     O3_CL         P  \
# 0      -0.696490  1.861055  0.821655 -0.432718  1.606353 -1.157352  1.863852
# 1      -0.696490  1.859035  0.842557 -0.306461  1.574038 -1.158623  1.864758
# 2      -0.696490  1.857015  0.863459 -0.180205  1.541723 -1.159895  1.865665
# 3      -0.696490  1.861862  0.869318 -0.213276  1.440525 -1.158921  1.866760
# 4      -0.696490  1.866709  0.875177 -0.246348  1.339327 -1.157947  1.867854
# ...          ...       ...       ...       ...       ...       ...       ...
# 221412 -0.140514  3.028325  1.791067  0.714938  1.139170 -0.953670  1.958696
# 221413 -0.140514  3.020985  1.810703  0.633013  1.337387 -0.952222  1.959225
# 221414 -0.140514  3.013646  1.830338  0.551088  1.535604 -0.950775  1.959753
# 221415 -0.140514  3.003005  1.849498  0.855557  2.107269 -0.950532  1.960301
# 221416 -0.140514  2.992363  1.868658  1.160026  2.678933 -0.950288  1.960848
#
# ...

# %%
model=CausalModel(data = normalised_key_atom1_data,treatment='H2O_DLH',outcome='OH_ATHOS',
        graph="""graph[directed 1 node[id "H2O_DLH" label "H2O_DLH"]
                    node[id "CH4_NOAA" label "CH4"]
                    node[id "CO_NOAA" label "CO"]
                    node[id "NO2_CL" label "NO2"]
                    node[id "P" label "P"]
                    node[id "T" label "T"]
                    node[id "O3_CL" label "O3"]
                    node[id "OH_ATHOS" label "OH_ATHOS"]
                    edge[source "CO_NOAA" target "OH_ATHOS"]
                    edge[source "NO2_CL" target "OH_ATHOS"]
                    edge[source "P" target "OH_ATHOS"]
                    edge[source "CH4_NOAA" target "OH_ATHOS"]
                    edge[source "T" target "OH_ATHOS"]
                    edge[source "H2O_DLH" target "OH_ATHOS"]
                    edge[source "O3_CL" target "OH_ATHOS"]]"""

        )
model.view_model()


display(Image(filename="causal_model.png"))
# Out:
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['H2O_DLH'] on outcome ['OH_ATHOS']

# %%
model=CausalModel(data = normalised_key_atom1_data,treatment='H2O_DLH',outcome='OH_ATHOS',
        graph="""graph[directed 1 node[id "H2O_DLH" label "H2O_DLH"]
                    node[id "CH4_NOAA" label "CH4"]
                    node[id "CO_NOAA" label "CO"]
                    node[id "NO2_CL" label "NO2"]
                    node[id "P" label "P"]
                    node[id "T" label "T"]
                    node[id "O3_CL" label "O3"]
                    node[id "OH_ATHOS" label "OH_ATHOS"]
                    edge[source "CO_NOAA" target "H2O_DLH"]
                    edge[source "NO2_CL" target "H2O_DLH"]
                    edge[source "P" target "H2O_DLH"]
                    edge[source "CH4_NOAA" target "H2O_DLH"]
                    edge[source "T" target "H2O_DLH"]
                    edge[source "H2O_DLH" target "OH_ATHOS"]
                    edge[source "O3_CL" target "H2O_DLH"]]"""

        )
model.view_model()


display(Image(filename="causal_model.png"))
# Out:
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['H2O_DLH'] on outcome ['OH_ATHOS']

# %%
model=CausalModel(data = normalised_key_atom1_data,treatment='H2O_DLH',outcome='OH_ATHOS',
        graph="""graph[directed 1 node[id "H2O_DLH" label "H2O_DLH"]
                    node[id "CH4_NOAA" label "CH4"]
                    node[id "CO_NOAA" label "CO"]
                    node[id "NO2_CL" label "NO2"]
                    node[id "P" label "P"]
                    node[id "T" label "T"]
                    node[id "O3_CL" label "O3"]
                    node[id "OH_ATHOS" label "OH_ATHOS"]
                    edge[source "CO_NOAA" target "OH_ATHOS"]
                    edge[source "NO2_CL" target "OH_ATHOS"]
                    edge[source "P" target "OH_ATHOS"]
                    edge[source "CH4_NOAA" target "OH_ATHOS"]
                    edge[source "T" target "OH_ATHOS"]
                    edge[source "H2O_DLH" target "OH_ATHOS"]
                    edge[source "OH_ATHOS" target "CH4_NOAA"]
                    edge[source "OH_ATHOS" target "CO_NOAA"]
                    edge[source "T" target "H2O_DLH"]
                    edge[source "T" target "O3_CL"]
                    edge[source "P" target "H2O_DLH"]
                    edge[source "NO2_CL" target "O3_CL"]
                    edge[source "NO2_CL" target "CH4_NOAA"]
                    edge[source "OH_ATHOS" target "NO2_CL"]
                    edge[source "O3_CL" target "OH_ATHOS"]]"""

        )
model.view_model()


display(Image(filename="causal_model.png"))
# Out:
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['H2O_DLH'] on outcome ['OH_ATHOS']

# %% [markdown]
# ### Suggesting H2O as a cause

# %%
# With graph
model=CausalModel(
        data = normalised_key_atom1_data, treatment='H2O_DLH', outcome='OH_ATHOS', common_causes="T")
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['H2O_DLH'] on outcome ['OH_ATHOS']

# %%
identified_estimand = model.identify_effect()
# Out:
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['U']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n] y
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:['T', 'CH4', 'O3', 'P', 'NO2', 'CO']

# %%
estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression", test_significance=True
)

print(estimate)

print("Causal Estimate is " + str(estimate.value))
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: OH_ATHOS~H2O_DLH
#                             OLS Regression Results
# ...
# Dep. Variable:               OH_ATHOS   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     5.677
# Date:                Mon, 23 Nov 2020   Prob (F-statistic):             0.0172
# Time:                        14:34:13   Log-Likelihood:            -3.1417e+05
# No. Observations:              221417   AIC:                         6.284e+05
# Df Residuals:                  221415   BIC:                         6.284e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
refute_results=model.refute_estimate(identified_estimand, estimate,
        method_name="random_common_cause")
print(refute_results)
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: OH_ATHOS~H2O_DLH+w_random
#                             OLS Regression Results
# ...
# Dep. Variable:               OH_ATHOS   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     2.885
# Date:                Mon, 23 Nov 2020   Prob (F-statistic):             0.0558
# Time:                        14:35:43   Log-Likelihood:            -3.1417e+05
# No. Observations:              221417   AIC:                         6.284e+05
# Df Residuals:                  221414   BIC:                         6.284e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### New example with P as the cause

# %%
# With graph
model=CausalModel(
        data = normalised_key_atom1_data, treatment='P', outcome='OH_ATHOS', common_causes="T")
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['P'] on outcome ['OH_ATHOS']

# %%
identified_estimand = model.identify_effect()
# Out:
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['U', 'T']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n] y
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]

# %%
estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression", test_significance=True)

print(estimate)

print("Causal Estimate is " + str(estimate.value))
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: OH_ATHOS~P+T
#                             OLS Regression Results
# ...
# Dep. Variable:               OH_ATHOS   R-squared:                       0.363
# Model:                            OLS   Adj. R-squared:                  0.363
# Method:                 Least Squares   F-statistic:                 6.311e+04
# Date:                Mon, 23 Nov 2020   Prob (F-statistic):               0.00
# Time:                        14:38:21   Log-Likelihood:            -2.6424e+05
# No. Observations:              221417   AIC:                         5.285e+05
# Df Residuals:                  221414   BIC:                         5.285e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
## Inverse causal relationship - ok.

# %% [markdown]
# ### Let's try JO1D

# %%
# With graph
model=CausalModel(
        data = normalised_key_atom1_data, treatment='jO3_O2_O1D_CAFS', outcome='OH_ATHOS', common_causes="P")
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['jO3_O2_O1D_CAFS'] on outcome ['OH_ATHOS']

# %%
identified_estimand = model.identify_effect()
# Out:
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['U', 'P']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n]
# Please respond with 'y' or 'n'
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n] y
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]

# %%
estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression", test_significance=True)

print(estimate)

print("Causal Estimate is " + str(estimate.value))
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: OH_ATHOS~jO3_O2_O1D_CAFS+P
#                             OLS Regression Results
# ...
# Dep. Variable:               OH_ATHOS   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                 2.344e+05
# Date:                Mon, 23 Nov 2020   Prob (F-statistic):               0.00
# Time:                        14:41:09   Log-Likelihood:            -1.8832e+05
# No. Observations:              221417   AIC:                         3.766e+05
# Df Residuals:                  221414   BIC:                         3.767e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
### Now JNO2, hoping for a similar result

# %%
# With graph
model=CausalModel(
        data = normalised_key_atom1_data, treatment='jNO2_NO_O3P_CAFS', outcome='OH_ATHOS', common_causes="T")
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['jNO2_NO_O3P_CAFS'] on outcome ['OH_ATHOS']

# %%
identified_estimand = model.identify_effect()
# Out:
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['U', 'T']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n]
# Please respond with 'y' or 'n'
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n] y
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]

# %%
estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression", test_significance=True)

print(estimate)

print("Causal Estimate is " + str(estimate.value))
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: OH_ATHOS~jNO2_NO_O3P_CAFS+T
#                             OLS Regression Results
# ...
# Dep. Variable:               OH_ATHOS   R-squared:                       0.474
# Model:                            OLS   Adj. R-squared:                  0.474
# Method:                 Least Squares   F-statistic:                 9.977e+04
# Date:                Mon, 23 Nov 2020   Prob (F-statistic):               0.00
# Time:                        14:42:55   Log-Likelihood:            -2.4305e+05
# No. Observations:              221417   AIC:                         4.861e+05
# Df Residuals:                  221414   BIC:                         4.861e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Now let's try methane

# %%
# With graph
model=CausalModel(
        data = normalised_key_atom1_data, treatment='CH4_NOAA', outcome='OH_ATHOS', common_causes="P")
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['CH4_NOAA'] on outcome ['OH_ATHOS']

# %%
identified_estimand = model.identify_effect()
# Out:
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['U', 'P']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n]
# Please respond with 'y' or 'n'
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n]
# Please respond with 'y' or 'n'
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n] y
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]

# %%
estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression", test_significance=True)

print(estimate)

print("Causal Estimate is " + str(estimate.value))
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: OH_ATHOS~CH4_NOAA+P
#                             OLS Regression Results
# ...
# Dep. Variable:               OH_ATHOS   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.427
# Method:                 Least Squares   F-statistic:                 8.264e+04
# Date:                Mon, 23 Nov 2020   Prob (F-statistic):               0.00
# Time:                        14:45:10   Log-Likelihood:            -2.5245e+05
# No. Observations:              221417   AIC:                         5.049e+05
# Df Residuals:                  221414   BIC:                         5.049e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Example from tutorial

# %%
# With graph
model=CausalModel(
        data = df,
        treatment=data["treatment_name"],
        outcome=data["outcome_name"],
        graph=data["gml_graph"]
        )
# Out:
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['v0'] on outcome ['y']

# %%
model.view_model()

# %%
from IPython.display import Image, display
display(Image(filename="causal_model.png"))

# %% [markdown]
# ### Identification

# %%
identified_estimand = model.identify_effect()
print(identified_estimand)
# Out:
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['W3', 'W1', 'W4', 'W0', 'W2', 'Unobserved Confounders']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n] y
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:['Z1', 'Z0']
# Estimand type: nonparametric-ate
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#   d
# ─────(Expectation(y|W3,W1,W4,W0,W2))
# d[v₀]
# Estimand assumption 1, Unconfoundedness: If U→{v0} and U→y then P(y|v0,W3,W1,W4,W0,W2,U) = P(y|v0,W3,W1,W4,W0,W2)
# ### Estimand : 2
# Estimand name: iv
# Estimand expression:
# Expectation(Derivative(y, [Z1, Z0])*Derivative([v0], [Z1, Z0])**(-1))
# ...

# %%
identified_estimand = model.identify_effect(proceed_when_unidentifiable=True)
print(identified_estimand)
# Out:
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['W3', 'W1', 'W4', 'W0', 'W2', 'Unobserved Confounders']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:['Z1', 'Z0']
# Estimand type: nonparametric-ate
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#   d
# ─────(Expectation(y|W3,W1,W4,W0,W2))
# d[v₀]
# Estimand assumption 1, Unconfoundedness: If U→{v0} and U→y then P(y|v0,W3,W1,W4,W0,W2,U) = P(y|v0,W3,W1,W4,W0,W2)
# ### Estimand : 2
# Estimand name: iv
# Estimand expression:
# Expectation(Derivative(y, [Z1, Z0])*Derivative([v0], [Z1, Z0])**(-1))
# ...

# %% [markdown]
# ### Estimation

# %%
causal_estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.propensity_score_stratification")
print(causal_estimate)
print("Causal Estimate is " + str(causal_estimate.value))
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Propensity Score Stratification Estimator
# INFO:dowhy.causal_estimator:b: y~v0+W3+W1+W4+W0+W2
# /home/shmh4/.conda/envs/netcdf/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: nonparametric-ate
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#   d
# ─────(Expectation(y|W3,W1,W4,W0,W2))
# d[v₀]
# Estimand assumption 1, Unconfoundedness: If U→{v0} and U→y then P(y|v0,W3,W1,W4,W0,W2,U) = P(y|v0,W3,W1,W4,W0,W2)
# ### Estimand : 2
# Estimand name: iv
# Estimand expression:
# Expectation(Derivative(y, [Z1, Z0])*Derivative([v0], [Z1, Z0])**(-1))
# Estimand assumption 1, As-if-random: If U→→y then ¬(U →→{Z1,Z0})
# ...

# %%
# Causal effect on the control group (ATC)
causal_estimate_att = model.estimate_effect(identified_estimand,
        method_name="backdoor.propensity_score_stratification",
        target_units = "atc")
print(causal_estimate_att)
print("Causal Estimate is " + str(causal_estimate_att.value))
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Propensity Score Stratification Estimator
# INFO:dowhy.causal_estimator:b: y~v0+W3+W1+W4+W0+W2
# /home/shmh4/.conda/envs/netcdf/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: nonparametric-ate
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#   d
# ─────(Expectation(y|W3,W1,W4,W0,W2))
# d[v₀]
# Estimand assumption 1, Unconfoundedness: If U→{v0} and U→y then P(y|v0,W3,W1,W4,W0,W2,U) = P(y|v0,W3,W1,W4,W0,W2)
# ### Estimand : 2
# Estimand name: iv
# Estimand expression:
# Expectation(Derivative(y, [Z1, Z0])*Derivative([v0], [Z1, Z0])**(-1))
# Estimand assumption 1, As-if-random: If U→→y then ¬(U →→{Z1,Z0})
# ...

# %% [markdown]
# ### Specify common causes and instruments

# %%
# Without graph
model= CausalModel(
        data=df,
        treatment=data["treatment_name"],
        outcome=data["outcome_name"],
        common_causes=data["common_causes_names"],
        effect_modifiers=data["effect_modifier_names"])
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['v0'] on outcome ['y']

# %%
model.view_model()

# %%
from IPython.display import Image, display
display(Image(filename="causal_model.png"))

# %%
identified_estimand = model.identify_effect(proceed_when_unidentifiable=True)
# Out:
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['U', 'W3', 'W1', 'W4', 'W0', 'W2']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]

# %%
estimate = model.estimate_effect(identified_estimand,
                                 method_name="backdoor.propensity_score_stratification")
print(estimate)
print("Causal Estimate is " + str(estimate.value))
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Propensity Score Stratification Estimator
# INFO:dowhy.causal_estimator:b: y~v0+W3+W1+W4+W0+W2
# /home/shmh4/.conda/envs/netcdf/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: nonparametric-ate
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#   d
# ─────(Expectation(y|W3,W1,W4,W0,W2))
# d[v₀]
# Estimand assumption 1, Unconfoundedness: If U→{v0} and U→y then P(y|v0,W3,W1,W4,W0,W2,U) = P(y|v0,W3,W1,W4,W0,W2)
# ### Estimand : 2
# Estimand name: iv
# No such variable found!
#
# ## Realized estimand
# b: y~v0+W3+W1+W4+W0+W2
# Target units: ate
#
# ## Estimate
# Mean value: 9.603400902273352
#
# Causal Estimate is 9.603400902273352

# %% [markdown]
# ### Refuting the estimate

# %%
res_random=model.refute_estimate(identified_estimand, estimate, method_name="random_common_cause")
print(res_random)
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Propensity Score Stratification Estimator
# INFO:dowhy.causal_estimator:b: y~v0+W3+W1+W4+W0+W2+w_random
# /home/shmh4/.conda/envs/netcdf/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Refute: Add a Random Common Cause
# Estimated effect:9.603400902273352
# New effect:9.710061519946407

# %% [markdown]
# ### Adding an unobserved common cause variable

# %%
res_unobserved=model.refute_estimate(identified_estimand, estimate, method_name="add_unobserved_common_cause",
                                     confounders_effect_on_treatment="binary_flip", confounders_effect_on_outcome="linear",
                                    effect_strength_on_treatment=0.01, effect_strength_on_outcome=0.02)
print(res_unobserved)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-4a76570d9ccc> in <module>
# ----> 1 res_unobserved=model.refute_estimate(identified_estimand, estimate, method_name="add_unobserved_common_cause",
#       2                                      confounders_effect_on_treatment="binary_flip", confounders_effect_on_outcome="linear",
#       3                                     effect_strength_on_treatment=0.01, effect_strength_on_outcome=0.02)
#       4 print(res_unobserved)
#
# ~/.conda/envs/netcdf/lib/python3.8/site-packages/dowhy/causal_model.py in refute_estimate(self, estimand, estimate, method_name, **kwargs)
#     315             **kwargs
#     316         )
# --> 317         res = refuter.refute_estimate()
#     318         return res
#     319
#
# ...

# %% [markdown]
# ### Replacing treatment with a random (placebo) variable

# %%
res_placebo=model.refute_estimate(identified_estimand, estimate,
        method_name="placebo_treatment_refuter", placebo_type="permute")
print(res_placebo)
# Out:
# INFO:dowhy.causal_refuters.placebo_treatment_refuter:Refutation over 100 simulated datasets of permute treatment
# INFO:dowhy.causal_estimator:INFO: Using Propensity Score Stratification Estimator
# INFO:dowhy.causal_estimator:b: y~placebo+W3+W1+W4+W0+W2
# /home/shmh4/.conda/envs/netcdf/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# INFO:dowhy.causal_estimator:INFO: Using Propensity Score Stratification Estimator
# INFO:dowhy.causal_estimator:b: y~placebo+W3+W1+W4+W0+W2
# /home/shmh4/.conda/envs/netcdf/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %% [markdown]
# ### Removing a random subset of the data

# %%
res_subset=model.refute_estimate(identified_estimand, estimate,
        method_name="data_subset_refuter", subset_fraction=0.9)
print(res_subset)
# Out:
# INFO:dowhy.causal_refuters.data_subset_refuter:Refutation over 0.9 simulated datasets of size 9000.0 each
# INFO:dowhy.causal_estimator:INFO: Using Propensity Score Stratification Estimator
# INFO:dowhy.causal_estimator:b: y~v0+W3+W1+W4+W0+W2
# /home/shmh4/.conda/envs/netcdf/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# INFO:dowhy.causal_estimator:INFO: Using Propensity Score Stratification Estimator
# INFO:dowhy.causal_estimator:b: y~v0+W3+W1+W4+W0+W2
# /home/shmh4/.conda/envs/netcdf/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
res_subset=model.refute_estimate(identified_estimand, estimate,
        method_name="data_subset_refuter", subset_fraction=0.9, random_seed = 1)
print(res_subset)
# Out:
# INFO:dowhy.causal_refuters.data_subset_refuter:Refutation over 0.9 simulated datasets of size 9000.0 each
# INFO:dowhy.causal_estimator:INFO: Using Propensity Score Stratification Estimator
# INFO:dowhy.causal_estimator:b: y~v0+W3+W1+W4+W0+W2
# /home/shmh4/.conda/envs/netcdf/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# INFO:dowhy.causal_estimator:INFO: Using Propensity Score Stratification Estimator
# INFO:dowhy.causal_estimator:b: y~v0+W3+W1+W4+W0+W2
# /home/shmh4/.conda/envs/netcdf/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %% [markdown]
# # Confounding example
# ### Suppose you are given some data with treatment and outcome. Can you determine whether the treatment causes the outcome, or the correlation is purely due to another common cause?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import dowhy
from dowhy import CausalModel
import dowhy.datasets, dowhy.plotter

# %%
rvar = 1 if np.random.uniform() >0.5 else 0
data_dict = dowhy.datasets.xy_dataset(10000, effect=rvar, sd_error=0.2)
df = data_dict['df']
print(df[["Treatment", "Outcome", "w0"]].head())
# Out:
#    Treatment    Outcome        w0
# 0   9.781908  19.254733  3.505136
# 1  10.113634  19.908103  3.995461
# 2   9.986367  20.186441  3.991654
# 3   5.061674  10.386285 -0.645939
# 4   8.798775  17.827273  3.054851

# %%
dowhy.plotter.plot_treatment_outcome(df[data_dict["treatment_name"]], df[data_dict["outcome_name"]],
                             df[data_dict["time_val"]])
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# ### Using DoWhy to resolve the mystery: Does Treatment cause Outcome?

# %%
model= CausalModel(
        data=df,
        treatment=data_dict["treatment_name"],
        outcome=data_dict["outcome_name"],
        common_causes=data_dict["common_causes_names"],
        instruments=data_dict["instrument_names"])
model.view_model(layout="dot")
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Treatment'] on outcome ['Outcome']

# %%
from IPython.display import Image, display
display(Image(filename="causal_model.png"))

# %% [markdown]
# ### Identify the causal effect using properties of the causal graph.

# %%
identified_estimand = model.identify_effect()
print(identified_estimand)
# Out:
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['w0', 'U']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n] y
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# Estimand type: nonparametric-ate
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#      d
# ────────────(Expectation(Outcome|w0))
# d[Treatment]
# Estimand assumption 1, Unconfoundedness: If U→{Treatment} and U→Outcome then P(Outcome|Treatment,w0,U) = P(Outcome|Treatment,w0)
# ### Estimand : 2
# Estimand name: iv
# No such variable found!

# %%
estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression")
print("Causal Estimate is " + str(estimate.value))

# Plot Slope of line between treamtent and outcome =causal effect
dowhy.plotter.plot_causal_effect(estimate, df[data_dict["treatment_name"]], df[data_dict["outcome_name"]])
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: Outcome~Treatment+w0
#                             OLS Regression Results
# ...
# Dep. Variable:                Outcome   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 4.053e+06
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):               0.00
# Time:                        11:29:09   Log-Likelihood:                 1772.7
# No. Observations:               10000   AIC:                            -3539.
# Df Residuals:                    9997   BIC:                            -3518.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
print("DoWhy estimate is " + str(estimate.value))
print ("Actual true causal effect was {0}".format(rvar))
# Out:
# DoWhy estimate is 1.0070176820289687
# Actual true causal effect was 1

# %% [markdown]
# # Refuting the estimate
# ### Add in a random common cause variable

# %%
res_random=model.refute_estimate(identified_estimand, estimate, method_name="random_common_cause")
print(res_random)
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: Outcome~Treatment+w0+w_random
#                             OLS Regression Results
# ...
# Dep. Variable:                Outcome   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.702e+06
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):               0.00
# Time:                        11:30:08   Log-Likelihood:                 1772.9
# No. Observations:               10000   AIC:                            -3538.
# Df Residuals:                    9996   BIC:                            -3509.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Replacing treatment with a random (placebo) variable

# %%
res_placebo=model.refute_estimate(identified_estimand, estimate,
        method_name="placebo_treatment_refuter", placebo_type="permute")
print(res_placebo)
# Out:
# INFO:dowhy.causal_refuters.placebo_treatment_refuter:Refutation over 100 simulated datasets of permute treatment
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: Outcome~placebo+w0
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: Outcome~placebo+w0
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: Outcome~placebo+w0
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: Outcome~placebo+w0
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: Outcome~placebo+w0
#                             OLS Regression Results
# ...
# Dep. Variable:                Outcome   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# ...

# %% [markdown]
# ### Removing a random subset of the data

# %%
res_subset=model.refute_estimate(identified_estimand, estimate,
        method_name="data_subset_refuter", subset_fraction=0.9)
print(res_subset)
# Out:
# INFO:dowhy.causal_refuters.data_subset_refuter:Refutation over 0.9 simulated datasets of size 9000.0 each
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: Outcome~Treatment+w0
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: Outcome~Treatment+w0
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: Outcome~Treatment+w0
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: Outcome~Treatment+w0
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: Outcome~Treatment+w0
#                             OLS Regression Results
# ...
# Dep. Variable:                Outcome   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# ...

# %% [markdown]
# ### Causal estimator is robust to: removing a random subset of the data (estimated effect still the same), replacing causal variable with placebo (estimated effect = 0), and adding in a random common cause variable (estimated effect remains the same)

# %%
import numpy as np
import pandas as pd
import logging

import dowhy
from dowhy import CausalModel
import dowhy.datasets
